# %% [markdown]
# <a href="https://colab.research.google.com/github/sjccc-z/lstm-oil/blob/main/Multivariate_Oil_Price_Prediction_Using_LSTM_%26_GRU_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Title : Multivariate Analysis & Oil Price Prediction Using GRU & LSTM**

# %% [markdown]
# **Problem Type** : Multivariate Forecasting

# %% [markdown]
# **Actionable Decision :** Whether to Invest or Not in the Commodity

# %% [markdown]
# Importing and installing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px
from scipy.stats import zscore as zs
from scipy import linalg as scipy_linalg
from sklearn.model_selection import train_test_split as split
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, GRU
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, mean_squared_log_error
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(1)
from google.colab import files
from keras.optimizers import SGD
from IPython.display import display, Image

# %%
##Matplotlib Parameters
import matplotlib.ticker as ticker
from pylab import rcParams
rcParams['axes.labelsize'] = 12
rcParams['xtick.labelsize'] = 12
rcParams['ytick.labelsize'] = 12
plt.style.context('fivethirtyeight')

# %%
##Installing Tensorflow-GPU
# %%capture
# !pip install tensorflow-gpu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/COMBINED.csv'
oil_df = pd.read_csv(file_path)
oil_df.head(2)
# Out:
#          Date    WTI   GOLD   SP 500  US DOLLAR INDEX  US 10YR BOND     DJU
# 0  04-01-2000  25.55  282.7  1411.75           100.10         6.499  289.10
# 1  05-01-2000  24.91  281.1  1413.50           100.05         6.599  292.64

# %% [markdown]
# # **Data Description :-**
#
# **Source of Data Collection**:Individual Data series collected from (https://in.investing.com/) between 4th Jan 2000 to 10th June 2019.
#
# **Data Dimentions :-**
#
# -> 4947 Attributes
#
# -> 7 Features
#
# -------------------------
# **Date**: Date of Trading
#
# **WTI** :  Includes spot values of West Texas Intermediate which is mix of crude oil traded on NYMEX.
#
# **GOLD** : With Increase in Oil price ,inflation increases and in turn GOLD futures also increases. Gold futures is a good indicator of economic situations.
#
# **SP 500** : Overall market
# stability can be ascertained by S&P 500 as it contains 500 large companies.Can indicate market sentiments and economic conditions.
#
# **US DOLLAR INDEX** : Represents US Dollar Index Futures . Foreign exchange market has quite an impact on oil prices since the US dollar is international metric to interpret the global economic conditions.
#
# **US 10YR BOND** :Represents US 10-Year Bond yeild . Is a certificate of
# loan with federal government that matures in 10 years. Great indicator of investor sentiment about the economy.
#
# **DJU**:Represents Dow Jones Utility Average.
# Performance of 15
# important utility stocks,these being sensitive to changes in the price of commodities such as natural gas or coal.
#
# Target Variable- (WTI)
#
# Features -(GOLD),(SP 500),(US DOLLAR INDEX),(US 10YR BOND),(DJU)
#
# ->Since this is a time series problem and WTI will be autoregressive ,we will use it also as a feature.

# %% [markdown]
# Getting to Know Our Data

# %%
oil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4947 entries, 0 to 4946
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             4947 non-null   object
#  1   WTI              4947 non-null   float64
#  2   GOLD             4941 non-null   float64
#  3   SP 500           4946 non-null   float64
#  4   US DOLLAR INDEX  4917 non-null   float64
#  5   US 10YR BOND     4920 non-null   float64
#  6   DJU              4859 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 270.7+ KB

# %% [markdown]
# During preprocessing :-
#
# ->We need to convert Date into DateTime
#
# ->Make Date column index .

# %%
oil_df.describe()
# Out:
#                WTI         GOLD       SP 500  US DOLLAR INDEX  US 10YR BOND  \
# count  4947.000000  4941.000000  4946.000000      4917.000000   4920.000000
# mean     62.068803   943.852311  1544.704848        90.503182      3.453490
# std      26.470270   473.656860   544.716725        11.691564      1.222532
# min      17.450000   255.100000   676.000000        71.304000      1.358000
# 25%      40.115000   424.000000  1150.250000        80.946000      2.382000
# 50%      59.300000  1088.500000  1356.250000        88.350000      3.389500
# 75%      83.725000  1329.800000  1945.687500        96.940000      4.413000
# max     145.290000  1888.700000  2948.500000       121.210000      6.790000
#
#                DJU
# count  4859.000000
# mean    459.169801
# std     147.334229
# min     167.570007
# 25%     359.664994
# 50%     438.119995
# 75%     553.309998
# max     812.909973

# %%
##Checking Missing Values
oil_df.isnull().sum()
# Out:
# Date                0
# WTI                 0
# GOLD                6
# SP 500              1
# US DOLLAR INDEX    30
# US 10YR BOND       27
# DJU                88
# dtype: int64

# %% [markdown]
# Missing Values-(Previous Day Imputation)

# %%
##Filling Missing Values with Previous Day Value
oil_df = oil_df.fillna(method='ffill')
oil_df.isnull().sum()
# Out:
# <ipython-input-114-756028127f2e>:2: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# Date               0
# WTI                0
# GOLD               0
# SP 500             0
# US DOLLAR INDEX    0
# US 10YR BOND       0
# DJU                0
# dtype: int64

# %%
##Converting Date column as DateTime format
oil_df['Date'] = pd.to_datetime(oil_df['Date'],format='%d-%m-%Y')

# %%
oil_df.dtypes
# Out:
# Date               datetime64[ns]
# WTI                       float64
# GOLD                      float64
# SP 500                    float64
# US DOLLAR INDEX           float64
# US 10YR BOND              float64
# DJU                       float64
# dtype: object

# %%
##Setting Date as Index
oil_df.set_index('Date',inplace=True)

# %%
oil_df.head(2)
# Out:
#               WTI   GOLD   SP 500  US DOLLAR INDEX  US 10YR BOND     DJU
# Date
# 2000-01-04  25.55  282.7  1411.75           100.10         6.499  289.10
# 2000-01-05  24.91  281.1  1413.50           100.05         6.599  292.64

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
##Line Plots Target & Features
data = oil_df
col_names = data.columns

fig = plt.figure(figsize=(24, 24))
plt.style.use('fivethirtyeight')
for i in range(6):
  ax = fig.add_subplot(6,1,i+1)
  ax.plot(data.iloc[:,i],label=col_names[i])
  data.iloc[:,i].rolling(100).mean().plot(label='Rolling Mean')
  ax.set_title(col_names[i])
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')
  plt.legend()
fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# Inferences :-
#
# -> WTI has mix of both UP and DOWN trends.
#
# -> Gold, DJU has UP Trend.
#
# -> US Dollar Index, US 10YR Bond has downward trend.

# %%
##Checking if Target and Features follow Normal Distribution
data = oil_df
fig = plt.figure(figsize=(24, 24))
plt.style.use('fivethirtyeight')
col_names = data.columns
for i in range(6):
  ax = fig.add_subplot(6,1,i+1)
  sns.distplot(data.iloc[:,i],label=col_names[i],color='dodgerblue').set_title("Distribution Plot of {}".format(col_names[i]),axes=ax)
  ax.tick_params(labelsize=12)
  plt.legend()
fig.tight_layout(pad=3.0)
plt.show()
# Out:
# <ipython-input-120-a8859130ad2a>:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-120-a8859130ad2a>:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-120-a8859130ad2a>:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-120-a8859130ad2a>:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-120-a8859130ad2a>:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-120-a8859130ad2a>:8: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# From above Distribution plots :-
#
# -> Most frequent values of WTI are in the range of 25 to 35.
#
# -> The WTI oil price values above 120
# are less frequent.
#
# -> All Features & WTI don't follow Normal Distribution.

# %%
## Temporary DataFrame
temp_data = oil_df
temp_data['Year'] = oil_df.index.year

# %%
##Box Plot Year Wise WTI
plt.figure(figsize=(18,10))
ax = sns.boxplot(x=temp_data['Year'], y=temp_data['WTI'])
ax.set_title('Box Plot Year Wise-WTI',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Box Plot Year Wise-WTI')

# %% [markdown]
# -> During the years 2007, 2008, and 2009 wide variations in the values of WTI have been
# observed.
#
# -> In the year 2008, which is the period of the financial crisis and huge volatality, the
# WTI oil price varies between 30-140$.
#
# -> Years 2002, 2008, 2014 & 2018 show outliers.

# %%
##Checking Series Lag Relationship(Auto-Correlation Nature)
##Citing Source-(https://machinelearningmastery.com/time-series-data-visualization-with-python/)
plt.figure(figsize=(10,10))
pd.plotting.lag_plot(oil_df['WTI'])
wti_series = oil_df['WTI']
n_lags = 7
cols = [wti_series]

for i in range(1,(n_lags + 1)):
	cols.append(wti_series.shift(i))
df = pd.concat(cols, axis=1)
cols = ['t+1']
for i in range(1,(n_lags + 1)):
	cols.append('t-' + str(i))
df.columns = cols
plt.figure(1)
for i in range(1,(n_lags + 1)):
	ax = plt.subplot(240 + i)
	ax.set_title('t+1 vs t-' + str(i))
	plt.scatter(x=df['t+1'].values, y=df['t-'+str(i)].values)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# -> The above Lag plot indicates that WTI has good positive correlation with each of its lagging orders.
#
# -> This kind of series is good for time series as its showing auto-regressive nature.

# %% [markdown]
# **Bivariate Analysis (WTI and Features)**

# %%
oil_df.drop(labels=['Year'],axis=1,inplace=True)

# %%
##Scaling Data to Observe Bivariate Analysis
sc = MinMaxScaler(feature_range=(0,1))
oil_df_scaled= sc.fit_transform(oil_df)

# %% [markdown]
# Since distribution is not normal we use Standardisation instead of Normalization.

# %%
##Scaled Data Glimse
oil_df_scaled[:2]
# Out:
# array([[0.06336045, 0.0168952 , 0.32376238, 0.57700477, 0.94642857,
#         0.18831933],
#        [0.05835419, 0.01591577, 0.32453245, 0.57600289, 0.964838  ,
#         0.19380482]])

# %%
##Comparing Movement of WTI wrt to Features
col_names = data.columns[1:]
scaled_features = oil_df_scaled[:,1:]
fig = plt.figure(figsize=(24, 24))
plt.style.use('fivethirtyeight')
for i in range(5):
  ax = fig.add_subplot(5,1,i+1)
  ax.plot(oil_df.index,scaled_features[:,i],label=col_names[i],c='red')
  ax.plot(oil_df.index,oil_df_scaled[:,0],label='WTI',c='grey')
  ax.set_title('WTI  & ' + col_names[i])
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')
  plt.legend()
fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# Inferences From Bivariate Feature Analysis :-
#
# ->During 2009 the value for both WTI and SP 500 drop sharply indicating that both these series are affected by same external factors. Move together.
#
#
# ->US Dollar index coinciding at several points
# with WTI, meaning that both the variables are strongly correlated. Apart from some common
# points the relationship seems to be inverse specifically when observing periods of 2000, 2007-
# 09 and 2010-16. Don't Move together.
#
#
# ->Both WTI and gold are fluctuating together.
# The gold seems to be lagging to the WTI in some ways especially if we observe years 2007
# wherein gold has not had much difference as WTI. Move together.
#
# ->US 10 year bond interest rates seem
# to be a leading indicator to volatility of WTI price, as we can see specifically from 2000-09 US
# bond progresses downward and then the WTI follows it. The US interest rate basically gave us
# a leading indication to financial crisis is what we have observed. Don't Move together.
#
# -> DJU & WTI move together.Very High correlation between 2003-2009.

# %% [markdown]
# **Multivariate Analysis**

# %%
fig = px.parallel_coordinates(oil_df,color='WTI',color_continuous_scale=px.colors.diverging.Tealrose,
                              title='Parallel Co-ordinates Plot')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b203460e-b3cd-4342-a20a-d273ab96ecb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b203460e-b3cd-4342-a20a-d273ab96ecb2")) {                    Plotly.newPlot(                        "b203460e-b3cd-4342-a20a-d273ab96ecb2",                        [{"dimensions":[{"label":"WTI","values":[25.55,24.91,24.78,24.22,24.67,25.77,26.28,26.69,28.02,28.85,29.54,29.66,28.2,27.83,28.28,27.84,27.32,27.22,27.64,28.22,27.55,28.03,28.82,28.45,28.02,28.77,29.43,29.44,30.25,30.06,30.05,29.46,29.51,29.62,29.39,29.97,30.35,30.13,30.43,31.77,31.69,31.51,32.18,34.13,31.26,31.69,31.76,32.02,31.69,30.72,31.09,30.91,29.43,28.0,27.46,27.31,28.02,27.79,27.09,26.45,26.7,26.9,26.43,25.45,25.83,25.69,25.04,23.85,24.14,25.41,25.38,25.57,25.89,26.11,27.35,25.88,26.04,25.33,24.65,25.42,25.74,25.87,26.89,26.75,26.98,27.29,28.09,28.65,28.1,29.11,29.62,29.92,29.73,29.32,30.33,29.89,28.61,28.78,29.93,30.51,30.0,30.35,29.01,30.14,30.35,29.7,29.75,29.95,29.78,30.2,31.74,32.56,32.85,32.95,32.33,31.69,33.05,31.37,32.19,32.25,31.63,32.06,31.9,32.72,32.5,30.67,29.99,30.28,29.69,29.7,30.32,31.47,31.4,30.83,31.94,31.42,30.93,28.56,28.02,27.95,27.81,28.02,28.18,27.43,27.79,28.26,28.66,29.96,28.91,29.12,30.35,31.34,31.02,31.94,31.67,31.8,31.94,31.99,32.47,31.22,32.02,31.63,32.03,32.87,32.74,33.32,33.12,33.38,33.83,34.9,35.39,33.63,35.14,34.28,33.82,34.07,35.92,36.88,36.51,37.2,34.0,32.68,31.57,31.5,31.46,30.34,30.84,32.18,32.07,31.43,30.53,30.86,31.86,33.18,33.25,36.06,34.99,32.92,32.99,33.48,32.91,33.75,33.76,33.37,32.96,33.71,32.74,32.81,32.7,33.25,32.54,32.71,32.86,33.4,33.24,33.92,34.02,34.47,34.87,35.58,35.12,35.45,35.22,35.16,35.4,35.38,34.22,34.63,33.82,32.02,31.22,29.53,29.85,29.35,28.44,29.5,29.68,28.74,27.99,28.87,29.76,29.33,25.77,25.98,26.18,26.64,26.47,25.85,26.8,27.21,28.0,28.14,27.95,27.32,27.64,29.48,29.41,30.05,30.29,29.6,30.45,32.19,32.19,29.57,29.05,29.36,29.77,29.06,29.06,28.66,29.82,31.19,30.55,30.35,31.27,31.59,31.03,30.51,30.36,29.71,28.8,29.16,28.58,28.53,28.82,29.04,28.42,28.13,27.39,27.62,27.84,28.6,28.32,29.0,28.39,28.01,28.0,27.59,26.41,26.55,26.74,26.15,25.96,26.8,26.54,27.3,27.48,27.75,26.31,26.32,26.29,25.59,26.19,27.12,27.26,27.06,27.28,28.48,28.18,28.25,28.79,28.24,27.95,27.82,27.28,27.61,26.86,27.29,28.44,28.27,28.46,28.94,27.8,28.45,28.36,27.77,27.39,28.23,28.52,28.55,28.71,28.98,28.86,28.91,29.91,29.98,29.74,29.58,28.41,28.38,28.66,28.55,28.37,27.93,28.13,28.24,27.72,27.75,28.33,29.04,29.18,28.84,29.04,28.51,27.55,27.48,26.5,26.56,26.83,27.25,26.98,25.61,25.56,26.25,25.95,26.24,27.02,28.21,27.59,27.49,27.11,26.8,26.59,26.06,25.57,24.89,24.7,25.59,26.12,26.31,26.84,26.73,27.02,26.63,26.35,26.77,27.71,27.62,27.74,27.94,27.54,27.64,28.05,27.82,28.01,27.56,27.4,26.68,27.18,27.91,26.37,26.63,26.9,26.67,27.17,27.05,26.55,27.2,26.93,26.95,27.58,28.03,27.63,29.53,28.81,27.7,26.72,26.59,25.97,22.01,21.81,22.38,22.74,23.43,23.28,22.79,22.08,22.63,22.39,22.45,22.48,22.53,23.34,22.5,22.29,22.0,21.81,21.31,21.83,21.76,21.85,22.33,22.01,22.03,22.15,21.87,21.18,20.39,20.18,20.02,19.92,20.09,21.17,22.22,21.2,21.67,19.74,17.45,18.03,17.72,19.15,18.96,18.69,19.48,19.22,18.62,19.44,20.09,19.65,19.49,18.54,19.04,18.37,18.08,18.36,18.12,19.23,19.22,19.36,19.8,19.28,19.62,21.27,20.9,20.41,19.84,21.01,20.37,21.62,21.48,21.25,20.18,20.38,19.68,18.89,18.9,18.86,17.97,18.0,18.34,19.5,19.7,19.99,20.05,19.58,19.08,19.48,20.38,20.07,20.07,19.78,19.64,20.26,21.41,20.73,21.18,21.23,21.5,20.88,20.29,20.95,21.07,20.48,21.41,21.29,21.74,22.4,22.45,23.17,23.15,23.71,23.84,24.31,24.2,24.16,24.56,24.51,25.11,24.88,24.9,25.61,25.35,24.99,25.36,25.87,26.31,26.88,27.71,27.56,26.58,26.21,26.54,25.82,26.13,24.99,23.47,24.57,24.75,25.94,26.18,26.38,26.27,26.62,26.38,26. ...

# %%
##To display on Github Viewer
##display(Image(filename='/content/drive/MyDrive/GitHub Projects/LSTM Oil Price/parallel plots img.png'))

# %% [markdown]
# Inferences From Parallel Co-ordinates Plot :-
#
# ->The higher values of WTI correpond to average values for GOLD,US 10 YR BOND,DJU. (Red shaded Path)
#
# ->Low Values of WTI correspond to High Values of US Dollar Index(Dark Green Shaded Path).

# %% [markdown]
# Since Target & Feature don't follow normal distribution , we will use
# **Spearman Correlation**.

# %% [markdown]
# **HeatMap**

# %%
##HeatMap Spearman Correlation
plt.figure(figsize=(8,8))
matrix = np.triu(oil_df.corr(method='spearman'))
heat_map = sns.heatmap(oil_df.corr(method='spearman'),annot=True,annot_kws={"size":14},cmap= 'YlGnBu',mask=matrix)
heat_map.set_yticklabels(heat_map.get_yticklabels(), rotation=60)
heat_map.set_xticklabels(heat_map.get_xticklabels(), rotation=60)
plt.tick_params(labelsize=12)
plt.title('Heatmap Spearman Correlation')
plt.style.use('fivethirtyeight')

# %% [markdown]
# -> The highest positive correlation with target variable WTI is with Gold(ρ:0.72)
#
# -> We also observe that SP500 and WTI have less correlation.(ρ : 0.23)
#
# -> US 10 YR Bond and WTI are moderately inversely correlated.(ρ : -0.39)
#
# -> DJU & WTI positive moderate correlation.(ρ : 0.41 )
#
# -> US Dollar Index & WTI have high correlation .(ρ : -0.86)
#
# -> We observe high correlation between DJU & SP 500 (ρ : 0.91)
# observed the SP 500 and DJU also have very high positive correlation.This is kind of Expected since both are indexes.

# %%
##Spearman Correlation In Tabular Form
oil_df.corr(method='spearman')
# Out:
#                       WTI      GOLD    SP 500  US DOLLAR INDEX  US 10YR BOND  \
# WTI              1.000000  0.720076  0.230186        -0.859079     -0.390108
# GOLD             0.720076  1.000000  0.515117        -0.537962     -0.846502
# SP 500           0.230186  0.515117  1.000000         0.104122     -0.460171
# US DOLLAR INDEX -0.859079 -0.537962  0.104122         1.000000      0.245306
# US 10YR BOND    -0.390108 -0.846502 -0.460171         0.245306      1.000000
# DJU              0.413496  0.669786  0.910919        -0.111127     -0.626274
#
#                       DJU
# WTI              0.413496
# GOLD             0.669786
# SP 500           0.910919
# US DOLLAR INDEX -0.111127
# US 10YR BOND    -0.626274
# DJU              1.000000

# %% [markdown]
# # Feature Selection
# We eliminate features by Filteration technique and use correlation factor .
# ->We eliminate all features having spearman correlation less than magnitude of
# 0.4.
# ->We remove SP 500 and US 10 YR Bond ,we also thereby eliminate Multicollinearity present among (SP 500 & DJU),(US 10 YR BOND & DJU),(GOLD & DJU).
#
# Features remaining : WTI ,GOLD , US DOLLAR INDEX.
# Since this is time series problem even WTI will be included as a feature as it is a autoregressive problem.

# %%
##Feature Selection
after_fs = oil_df[['WTI','GOLD','US DOLLAR INDEX']]
after_fs.head(3)
# Out:
#               WTI   GOLD  US DOLLAR INDEX
# Date
# 2000-01-04  25.55  282.7           100.10
# 2000-01-05  24.91  281.1           100.05
# 2000-01-06  24.78  281.4           100.34

# %% [markdown]
# # **Outlier Elimination**

# %% [markdown]
# **(Method-1) Financial Crisis Outlier Removal (2007-2009)**

# %% [markdown]
# We observed financial crisis from 2007 to 2009.
# We remove data points from mid of 2007 to mid of 2019 as this was a big crisis and led to lot of volatality of oil price movement as observed earlier.
# We eliminated 482 outliers.

# %%
before_2007 = after_fs['2000-01':'2007-06']
after_2009 = after_fs['2009-06':'2019-06']
fin_out = pd.concat([before_2007,after_2009],axis=0)
fin_out.shape
# Out:
# (4465, 3)

# %% [markdown]
# **(Method-2) Z-Score Outlier Removal Technique**

# %% [markdown]
# We can use Z-scores to detect outliers by calculating how many standard deviations away is a point from the mean.

# %%
zscore = np.abs(zs(after_fs['WTI']))
zscore_df = after_fs.copy()
zscore_df['zscore'] = zscore
zscore_df.head(5)
# Out:
#               WTI   GOLD  US DOLLAR INDEX    zscore
# Date
# 2000-01-04  25.55  282.7           100.10  1.379755
# 2000-01-05  24.91  281.1           100.05  1.403936
# 2000-01-06  24.78  281.4           100.34  1.408847
# 2000-01-07  24.22  281.9           100.50  1.430005
# 2000-01-10  24.67  281.7           100.65  1.413003

# %%
##Considering Outliers of more than +-2.5 zscore as outliers
len(zscore_df[zscore_df['zscore']>2.5])
# Out:
# 37

# %%
zscore_df = zscore_df.loc[zscore_df['zscore']<2.5,['WTI','GOLD','US DOLLAR INDEX']]
zscore_df.shape
# Out:
# (4910, 3)

# %% [markdown]
# We considered all points of more than 2.5 times away from mean as outliers and removed 37 datapoints.
# Z-score can be calculated on univariate series so we used it on our target variable WTI and removed corresponding points.

# %% [markdown]
# **(Method-3) Mahalanobis Distance Outlier Removal Technique**

# %% [markdown]
# Mahalanobis distance is distance between two points in a multivariate space. It can be effectively used to eliminate outliers when :-
#
# -> There is correlation with target variable.
#
# -> Multi-dimensional distance is possible otherwise not possible in Euclidean distance.

# %%
## Citing Source : https://www.machinelearningplus.com/statistics/mahalanobis-distance/
##Outlier Removal Method-3-Mahalanobis Distance
def mahalanobis(x=None, data=None, cov=None):
    """Compute the Mahalanobis Distance between each row of x and the data
    x    : vector or matrix of data with, say, p columns.
    data : ndarray of the distribution from which Mahalanobis distance of each observation of x is to be computed.
    cov  : covariance matrix (p x p) of the distribution. If None, will be computed from data.
    """
    x_minus_mu = x - np.mean(data)
    if not cov:
        cov = np.cov(data.values.T)
    inv_covmat = scipy_linalg.inv(cov)
    left_term = np.dot(x_minus_mu, inv_covmat)
    mahal = np.dot(left_term, x_minus_mu.T)
    return mahal.diagonal()

# %%
mah_df = after_fs.copy()
mah_df['Mahalanobis'] = mahalanobis(x=mah_df, data=mah_df)
mah_df.head(3)
# Out:
#               WTI   GOLD  US DOLLAR INDEX  Mahalanobis
# Date
# 2000-01-04  25.55  282.7           100.10  3791.532794
# 2000-01-05  24.91  281.1           100.05  3797.672788
# 2000-01-06  24.78  281.4           100.34  3793.602982

# %%
sns.distplot(mah_df['Mahalanobis'])
# Out:
# <ipython-input-139-1550048091a2>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Mahalanobis', ylabel='Density'>

# %%
##We consider points with Mahalanobis distance greater than 8 to be outliers.
len(mah_df[mah_df['Mahalanobis']>8])
# Out:
# 4947

# %% [markdown]
# We removed 145 datapoints by using Mahalanobis distance.

# %%
mah_df = mah_df.loc[mah_df['Mahalanobis']<8,['WTI','GOLD','US DOLLAR INDEX']]

# %% [markdown]
# # Data Preparation for Modelling

# %% [markdown]
# **Train-Test Split**

# %%
fin_train,fin_test = split(fin_out,train_size=0.7,shuffle=False)
z_train,z_test = split(zscore_df,train_size=0.7,shuffle=False)
##mah_train,mah_test = split(mah_df,train_size=0.7,shuffle=False)
van_train,van_test = split(after_fs,train_size=0.7,shuffle=False)

# %%
print('Fin Outlier Dataset')
print(fin_train.shape)
print(fin_test.shape)
print('Zscore Dataset')
print(z_train.shape)
print(z_test.shape)
##print('Mahalanobis Dataset')
##print(mah_train.shape)
##print(mah_test.shape)
print('Vanilla Model-No Outlier Elimination')
print(van_train.shape)
print(van_test.shape)
# Out:
# Fin Outlier Dataset
# (3125, 3)
# (1340, 3)
# Zscore Dataset
# (3437, 3)
# (1473, 3)
# Vanilla Model-No Outlier Elimination
# (3462, 3)
# (1485, 3)

# %% [markdown]
# **Scaling Data for Model**

# %%
##We need 2 scalers per model -Train and Test require different scalers
sc1 = MinMaxScaler(feature_range=(0,1))
sc2 = MinMaxScaler(feature_range=(0,1))

# %% [markdown]
# We will carry out Standardisation after train-test split to prevent overfitting.

# %% [markdown]
# LSTM /GRU stores data by taking in number of  timesteps for 1 output. So suppose we give 60 timesteps , that means for 61st day the model considers 1-60 days for sequence and so on.

# %%
##Function to Prepare Training Data for LSTM
def prepare_train_data_lstm(scaler,train_data,n_dim):
  input_data = scaler.fit_transform(train_data.values)
  print('Shape of Input Data Initially',input_data.shape)
  timesteps = 60
  global X1
  X1 = []
  global y1
  y1=[]
  for i in range(len(input_data)-timesteps-1):
    t=[]
    for j in range(0,timesteps):

        t.append(input_data[[(i+j)], :])
    X1.append(t)
    y1.append(input_data[i+ timesteps,0])

  X1, y1= np.array(X1), np.array(y1)
  print('Shape of Train Part after transformation',X1.shape)
  print('Shape of Test Part after transformation ',y1.shape)

  X1 = X1.reshape(X1.shape[0],timesteps, n_dim)
  print('Final Shape ',X1.shape)
  return X1,y1

# %%
##LSTM Model Function
def lstm_model(scaler,train_data,n_dim):
#initialize model
  prepare_train_data_lstm(scaler,train_data,n_dim)

  global model
  model = Sequential()

#layer 1 of LSTM
  model.add(LSTM(units=30,return_sequences=True,input_shape=(X1.shape[1],n_dim)))
  model.add(Dropout(0.2))

#layer 2 of LSTM
  model.add(LSTM(units=30,return_sequences=True))
  model.add(Dropout(0.2))

#layer 3 of LSTM
  model.add(LSTM(units=30,return_sequences=True))
  model.add(Dropout(0.2))

#layer 4 of LSTM
  model.add(LSTM(units=30))
  model.add(Dropout(0.2))

#Output layer of model
  model.add(Dense(units=1))

  optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
#compiling the model
  model.compile(optimizer=optimizer,loss='mean_squared_error')
  model.fit(X1, y1, epochs=50, batch_size=32)

# %%
##Function to Prepare Test Data
def prepare_test_data_lstm(scaler,test_data,n_dim):
  inputs = scaler.transform(test_data.values)
  global X_test
  X_test = []
  timesteps = 60
  for i in range(len(inputs)-timesteps-1):
      t=[]
      for j in range(0,timesteps):

          t.append(inputs[[(i+j)], :])
      X_test.append(t)
  X_test = np.array(X_test)
  X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], n_dim))
  print('Shape of Test Dataset',X_test.shape)

# %%
##Function to Predict Data
def predict_data(model_name,scaler_pred,test_data,X_test,Outlier_method,n_dim):

  pred = model_name.predict(X_test)
  print(len(test_data[61:]))
  set_scale = scaler_pred.fit_transform(test_data.iloc[61:,0].values.reshape(-1,1))
  pred_descale = scaler_pred.inverse_transform(pred)
  global pred_df
  pred_df = pd.DataFrame(pred_descale,columns=['Predicted -'+str(Outlier_method)])
  return pred_df

# %%
##Function to Calculate Result Metrics
def result_metrics_forecast(test_series,forecast_series,model_name,out_name):
  print('Result Metrics for ' +  str(model_name) + ' -{} Outlier Removal Technique'.format(out_name))
  print('R2 Score : ',round(r2_score(test_series,forecast_series),3))
  print('Mean Squared Error : ',round(mean_squared_error(test_series,forecast_series),3))
  print('Mean Absolute Error : ',round(mean_absolute_error(test_series,forecast_series),3))
  fig = plt.figure(figsize=(10,10))
  plt.plot(test_series.index,test_series,label='Actual')
  plt.plot(test_series.index,forecast_series,label='Predicted')
  plt.title(str(model_name) + ' -Forecasting Using {} Outlier Removal Technique'.format(out_name))
  plt.ylabel('Price')
  plt.legend()

# %% [markdown]
# # Hyper-parameter Tuning Learning Rate

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor = 'loss',patience = 20)
X1,y1 = prepare_train_data_lstm(sc1,fin_train,3)
# Out:
# Shape of Input Data Initially (3125, 3)
# Shape of Train Part after transformation (3064, 60, 1, 3)
# Shape of Test Part after transformation  (3064,)
# Final Shape  (3064, 60, 3)

# %%
"""
About this model : -
3 Layers of LSTM
1 Hidden Layer
Output Layer- learning rate is being optimized
Optimizer function is Adam
"""
import tensorflow as tf

## 4 layers of LSTM Model
model_simple = Sequential()

#layer 1 of LSTM
model_simple.add(LSTM(units=64,return_sequences=True,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

#layer 2 of LSTM
model_simple.add(LSTM(units=32,return_sequences=True,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

#layer 3 of LSTM
model_simple.add(LSTM(units=32,return_sequences=True,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

#layer 4 of LSTM
model_simple.add(LSTM(units=16,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

##Hidden Layer
model_simple.add(Dense(units=16))
#Output layer of model
model_simple.add(Dense(units=1))


#compiling the model
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 10))
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-8)
model_simple.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=['mae'])

##Model Fit
history_simple = model_simple.fit(X1, y1, epochs=200, batch_size=32,callbacks=[lr_schedule],validation_split=0.3,shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0280 - mae: 0.1827 - val_loss: 0.4347 - val_mae: 0.9291 - learning_rate: 1.0000e-08
# Epoch 2/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0280 - mae: 0.1825 - val_loss: 0.4346 - val_mae: 0.9291 - learning_rate: 1.2589e-08
# Epoch 3/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0279 - mae: 0.1821 - val_loss: 0.4346 - val_mae: 0.9290 - learning_rate: 1.5849e-08
# Epoch 4/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0280 - mae: 0.1824 - val_loss: 0.4345 - val_mae: 0.9289 - learning_rate: 1.9953e-08
# Epoch 5/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0278 - mae: 0.1811 - val_loss: 0.4344 - val_mae: 0.9288 - learning_rate: 2.5119e-08
# Epoch 6/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0278 - mae: 0.1811 - val_loss: 0.4342 - val_mae: 0.9286 - learning_rate: 3.1623e-08
# Epoch 7/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0280 - mae: 0.1826 - val_loss: 0.4341 - val_mae: 0.9285 - learning_rate: 3.9811e-08
# Epoch 8/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0277 - mae: 0.1809 - val_loss: 0.4339 - val_mae: 0.9282 - learning_rate: 5.0119e-08
# Epoch 9/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0278 - mae: 0.1814 - val_loss: 0.4336 - val_mae: 0.9279 - learning_rate: 6.3096e-08
# Epoch 10/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0277 - mae: 0.1809 - val_loss: 0.4332 - val_mae: 0.9275 - learning_rate: 7.9433e-08
# Epoch 11/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0278 - mae: 0.1813 - val_loss: 0.4328 - val_mae: 0.9271 - learning_rate: 1.0000e-07
# Epoch 12/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0277 - mae: 0.1809 - val_loss: 0.4323 - val_mae: 0.9265 - learning_rate: 1.2589e-07
# Epoch 13/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0276 - mae: 0.1803 - val_loss: 0.4316 - val_mae: 0.9257 - learning_rate: 1.5849e-07
# Epoch 14/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0273 - mae: 0.1790 - val_loss: 0.4307 - val_mae: 0.9248 - learning_rate: 1.9953e-07
# Epoch 15/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0273 - mae: 0.1786 - val_loss: 0.4297 - val_mae: 0.9237 - learning_rate: 2.5119e-07
# Epoch 16/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0273 - mae: 0.1786 - val_loss: 0.4283 - val_mae: 0.9222 - learning_rate: 3.1623e-07
# Epoch 17/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0271 - mae: 0.1780 - val_loss: 0.4267 - val_mae: 0.9204 - learning_rate: 3.9811e-07
# Epoch 18/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0266 - mae: 0.1752 - val_loss: 0.4246 - val_mae: 0.9182 - learning_rate: 5.0119e-07
# Epoch 19/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0265 - mae: 0.1747 - val_loss: 0.4221 - val_mae: 0.9154 - learning_rate: 6.3096e-07
# Epoch 20/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0264 - mae: 0.1746 - val_loss: 0.4189 - val_mae: 0.9119 - learning_rate: 7.9433e-07
# Epoch 21/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0259 - mae: 0.1723 - val_loss: 0.4149 - val_mae: 0.9075 - learning_rate: 1.0000e-06
# Epoch 22/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0252 - mae: 0.1683 - val_loss: 0.4101 - val_mae: 0.9021 - learning_rate: 1.2589e-06
# Epoch 23/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0246 - mae: 0.1647 - val_loss: 0.4041 - val_mae: 0.8955 - learning_rate: 1.5849e-06
# Epoch 24/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0239 - mae: 0.1616 - val_loss: 0.3969 - val_mae: 0.8873 - learning_rate: 1.9953e-06
# Epoch 25/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0230 - mae: 0.1570 - val_loss: 0.3879 - val_mae: 0.8771 - learning_rate: 2.5119e-06
# Epoch 26/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0220 - mae: 0.1503 - val_loss: 0.3768 - val_mae: 0.8645 - learning_rate: 3.1623e-06
# Epoch 27/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0209 - mae: 0.1445 - val_loss: 0.3636 - val_mae: 0.8491 - learning_rate: 3.9811e-06
# Epoch 28/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0194 - mae: 0.1365 - val_loss: 0.3473 - val_mae: 0.8296 - learning_rate: 5.0119e-06
# Epoch 29/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0179 - mae: 0.1262 - val_loss: 0.3265 - val_mae: 0.8043 - learning_rate: 6.3096e-06
# Epoch 30/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0161 - mae: 0.1175 - val_loss: 0.3001 - val_mae: 0.7708 - learning_rate: 7.9433e-06
# Epoch 31/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0142 - mae: 0.1081 - val_loss: 0.2646 - val_mae: 0.7234 - learning_rate: 1.0000e-05
# Epoch 32/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0116 - mae: 0.0976 - val_loss: 0.2146 - val_mae: 0.6508 - learning_rate: 1.2589e-05
# Epoch 33/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0099 - mae: 0.0994 - val_loss: 0.1488 - val_mae: 0.5406 - learning_rate: 1.5849e-05
# Epoch 34/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0090 - mae: 0.1072 - val_loss: 0.0798 - val_mae: 0.3932 - learning_rate: 1.9953e-05
# Epoch 35/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0088 - mae: 0.1123 - val_loss: 0.0321 - val_mae: 0.2437 - learning_rate: 2.5119e-05
# Epoch 36/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0050 - mae: 0.0830 - val_loss: 0.0114 - val_mae: 0.1350 - learning_rate: 3.1623e-05
# Epoch 37/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - mae: 0.0425 - val_loss: 0.0091 - val_mae: 0.1189 - learning_rate: 3.9811e-05
# Epoch 38/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0020 - mae: 0.0455 - val_loss: 0.0075 - val_mae: 0.1059 - learning_rate: 5.0119e-05
# Epoch 39/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0017 - mae: 0.0406 - val_loss: 0.0087 - val_mae: 0.1162 - learning_rate: 6.3096e-05
# Epoch 40/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0016 - mae: 0.0405 - val_loss: 0.0086 - val_mae: 0.1159 - learning_rate: 7.9433e-05
# Epoch 41/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0381 - val_loss: 0.0100 - val_mae: 0.1266 - learning_rate: 1.0000e-04
# Epoch 42/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0378 - val_loss: 0.0115 - val_mae: 0.1380 - learning_rate: 1.2589e-04
# Epoch 43/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mae: 0.0368 - val_loss: 0.0062 - val_mae: 0.0953 - learning_rate: 1.5849e-04
# Epoch 44/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - mae: 0.0441 - val_loss: 0.0058 - val_mae: 0.0913 - learning_rate: 1.9953e-04
# Epoch 45/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0035 - mae: 0.0673 - val_loss: 0.0040 - val_mae: 0.0734 - learning_rate: 2.5119e-04
# Epoch 46/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - mae: 0.0526 - val_loss: 0.0037 - val_mae: 0.0705 - learning_rate: 3.1623e-04
# Epoch 47/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - mae: 0.0559 - val_loss: 0.0034 - val_mae: 0.0678 - learning_rate: 3.9811e-04
# Epoch 48/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0030 - mae: 0.0626 - val_loss: 0.0040 - val_mae: 0.0733 - learning_rate: 5.0119e-04
# Epoch 49/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0015 - mae: 0.0423 - val_loss: 0.0043 - val_mae: 0.0765 - learning_rate: 6.3096e-04
# Epoch 50/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0047 - mae: 0.0790 - val_loss: 0.0043 - val_mae: 0.0764 - learning_rate: 7.9433e-04
# Epoch 51/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0405 - val_loss: 0.0040 - val_mae: 0.0739 - learning_rate: 0.0010
# Epoch 52/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0052 - mae: 0.0836 - val_loss: 0.0035 - val_mae: 0.0695 - learning_rate: 0.0013
# Epoch 53/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0399 - val_loss: 0.0037 - val_mae: 0.0709 - learning_rate: 0.0016
# Epoch 54/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0062 - mae: 0.0902 - val_loss: 0.0063 - val_mae: 0.0942 - learning_rate: 0.0020
# Epoch 55/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - mae: 0.0468 - val_loss: 0.0037 - val_mae: 0.0714 - learning_rate: 0.0025
# Epoch 56/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - mae: 0.0515 - val_loss: 0.0041 - val_mae: 0.0750 - learning_rate: 0.0032
# Epoch 57/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0054 - mae: 0.0842 - val_loss: 0.0057 - val_mae: 0.0891 - learning_rate: 0.0040
# Epoch 58/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0042 - mae: 0.0748 - val_loss: 0.0056 - val_mae: 0.0884 - learning_rate: 0.0050
# Epoch 59/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0101 - mae: 0.1044 - val_loss: 0.0132 - val_mae: 0.1462 - learning_rate: 0.0063
# Epoch 60/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - mae: 0.0468 - val_loss: 0.0049 - val_mae: 0.0823 - learning_rate: 0.0079
# Epoch 61/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0101 - mae: 0.1016 - val_loss: 0.0143 - val_mae: 0.1516 - learning_rate: 0.0100
# Epoch 62/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0092 - mae: 0.0994 - val_loss: 0.0073 - val_mae: 0.1019 - learning_rate: 0.0126
# Epoch 63/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0208 - mae: 0.1281 - val_loss: 0.0143 - val_mae: 0.1512 - learning_rate: 0.0158
# Epoch 64/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0165 - mae: 0.1086 - val_loss: 0.0210 - val_mae: 0.1899 - learning_rate: 0.0200
# Epoch 65/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0187 - mae: 0.1381 - val_loss: 0.0108 - val_mae: 0.1276 - learning_rate: 0.0251
# Epoch 66/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0206 - mae: 0.1357 - val_loss: 0.0311 - val_mae: 0.2371 - learning_rate: 0.0316
# Epoch 67/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0170 - mae: 0.1383 - val_loss: 0.0250 - val_mae: 0.2096 - learning_rate: 0.0398
# Epoch 68/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0182 - mae: 0.1506 - val_loss: 0.0530 - val_mae: 0.3162 - learning_rate: 0.0501
# Epoch 69/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0115 - mae: 0.1145 - val_loss: 0.0374 - val_mae: 0.2622 - learning_rate: 0.0631
# Epoch 70/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0138 - mae: 0.1265 - val_loss: 0.0192 - val_mae: 0.1800 - learning_rate: 0.0794
# Epoch 71/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0224 - mae: 0.1645 - val_loss: 0.0405 - val_mae: 0.2738 - learning_rate: 0.1000
# Epoch 72/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0110 - mae: 0.0971 - val_loss: 0.0347 - val_mae: 0.2517 - learning_rate: 0.1259
# Epoch 73/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0308 - mae: 0.1954 - val_loss: 0.0153 - val_mae: 0.1571 - learning_rate: 0.1585
# Epoch 74/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0293 - mae: 0.1996 - val_loss: 0.0162 - val_mae: 0.1625 - learning_rate: 0.1995
# Epoch 75/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0347 - mae: 0.1966 - val_loss: 0.0461 - val_mae: 0.2933 - learning_rate: 0.2512
# Epoch 76/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0180 - mae: 0.1396 - val_loss: 0.0486 - val_mae: 0.3019 - learning_rate: 0.3162
# Epoch 77/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0188 - mae: 0.1581 - val_loss: 0.0462 - val_mae: 0.2938 - learning_rate: 0.3981
# Epoch 78/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0198 - mae: 0.1496 - val_loss: 0.0360 - val_mae: 0.2566 - learning_rate: 0.5012
# Epoch 79/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 3.2654 - mae: 3.7002 - val_loss: 0.0188 - val_mae: 0.1774 - learning_rate: 0.6310
# Epoch 80/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0978 - mae: 0.3335 - val_loss: 0.0332 - val_mae: 0.2457 - learning_rate: 0.7943
# Epoch 81/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0196 - mae: 0.1513 - val_loss: 0.0349 - val_mae: 0.2526 - learning_rate: 1.0000
# Epoch 82/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0209 - mae: 0.1571 - val_loss: 0.0127 - val_mae: 0.1404 - learning_rate: 1.2589
# Epoch 83/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 30.9339 - mae: 31.2958 - val_loss: 104.5944 - val_mae: 105.0944 - learning_rate: 1.5849
# Epoch 84/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 42.0496 - mae: 42.5496 - val_loss: 23.7469 - val_mae: 24.2469 - learning_rate: 1.9953
# Epoch 85/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7576 - mae: 8.2429 - val_loss: 0.5924 - val_mae: 1.0923 - learning_rate: 2.5119
# Epoch 86/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0350 - mae: 0.2424 - val_loss: 0.0212 - val_mae: 0.1904 - learning_rate: 3.1623
# Epoch 87/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0325 - mae: 0.1953 - val_loss: 0.0203 - val_mae: 0.1860 - learning_rate: 3.9811
# Epoch 88/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0358 - mae: 0.2092 - val_loss: 0.0358 - val_mae: 0.2560 - learning_rate: 5.0119
# Epoch 89/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0350 - mae: 0.2167 - val_loss: 0.0261 - val_mae: 0.2146 - learning_rate: 6.3096
# Epoch 90/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0431 - mae: 0.2672 - val_loss: 0.0112 - val_mae: 0.1301 - learning_rate: 7.9433
# Epoch 91/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0843 - mae: 0.3485 - val_loss: 0.0207 - val_mae: 0.1882 - learning_rate: 10.0000
# Epoch 92/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 30.1743 - mae: 30.6157 - val_loss: 3601.9375 - val_mae: 3602.4375 - learning_rate: 12.5893
# Epoch 93/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 25495.9668 - mae: 25496.4668 - val_loss: 6660.9839 - val_mae: 6661.4839 - learning_rate: 15.8489
# Epoch 94/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6684.4653 - mae: 6684.9653 - val_loss: 602.5816 - val_mae: 603.0816 - learning_rate: 19.9526
# Epoch 95/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1165.0687 - mae: 1165.5687 - val_loss: 29.5626 - val_mae: 30.0626 - learning_rate: 25.1189
# Epoch 96/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 241.1284 - mae: 241.6280 - val_loss: 47.2152 - val_mae: 47.7152 - learning_rate: 31.6228
# Epoch 97/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 103.0842 - mae: 103.5829 - val_loss: 144.4566 - val_mae: 144.9566 - learning_rate: 39.8107
# Epoch 98/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 8340.1680 - mae: 8340.6680 - val_loss: 32829.6289 - val_mae: 32830.1289 - learning_rate: 50.1187
# Epoch 99/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 412226.7812 - mae: 412227.3125 - val_loss: 138331.3438 - val_mae: 138331.8438 - learning_rate: 63.0957
# Epoch 100/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 113153.2031 - mae: 113153.7031 - val_loss: 11493.8066 - val_mae: 11494.3066 - learning_rate: 79.4328
# Epoch 101/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8695.9600 - mae: 8696.4600 - val_loss: 1038.9183 - val_mae: 1039.4183 - learning_rate: 100.0000
# Epoch 102/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 14746.5742 - mae: 14747.0742 - val_loss: 1302.8033 - val_mae: 1303.3033 - learning_rate: 125.8925
# Epoch 103/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3241.2083 - mae: 3241.7083 - val_loss: 42233.5156 - val_mae: 42234.0156 - learning_rate: 158.4893
# Epoch 104/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2162714.5000 - mae: 2162714.7500 - val_loss: 4009438.2500 - val_mae: 4009439.5000 - learning_rate: 199.5262
# Epoch 105/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2193332.2500 - mae: 2193332.7500 - val_loss: 16991.8398 - val_mae: 16992.3398 - learning_rate: 251.1886
# Epoch 106/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 81160.3594 - mae: 81160.8594 - val_loss: 3073.3118 - val_mae: 3073.8118 - learning_rate: 316.2278
# Epoch 107/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 33302.1797 - mae: 33302.6797 - val_loss: 14637.5283 - val_mae: 14638.0283 - learning_rate: 398.1072
# Epoch 108/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2100849.2500 - mae: 2100849.5000 - val_loss: 6300303.5000 - val_mae: 6300304.0000 - learning_rate: 501.1872
# Epoch 109/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3287378.0000 - mae: 3287378.7500 - val_loss: 1015707.2500 - val_mae: 1015707.6875 - learning_rate: 630.9573
# Epoch 110/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 5983455.5000 - mae: 5983456.0000 - val_loss: 107157.4062 - val_mae: 107157.9141 - learning_rate: 794.3282
# Epoch 111/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8968947.0000 - mae: 8968948.0000 - val_loss: 7034527.0000 - val_mae: 7034528.5000 - learning_rate: 1000.0000
# Epoch 112/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 28009516.0000 - mae: 28009516.0000 - val_loss: 11136068.0000 - val_mae: 11136075.0000 - learning_rate: 1258.9254
# Epoch 113/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4960400.5000 - mae: 4960400.5000 - val_loss: 329208.5938 - val_mae: 329209.0938 - learning_rate: 1584.8932
# Epoch 114/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2122757.2500 - mae: 2122758.0000 - val_loss: 29301050.0000 - val_mae: 29301050.0000 - learning_rate: 1995.2623
# Epoch 115/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 140212624.0000 - mae: 140212624.0000 - val_loss: 140114672.0000 - val_mae: 140114672.0000 - learning_rate: 2511.8865
# Epoch 116/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 503475328.0000 - mae: 503475328.0000 - val_loss: 600174656.0000 - val_mae: 600174656.0000 - learning_rate: 3162.2776
# Epoch 117/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 503538528.0000 - mae: 503538528.0000 - val_loss: 1265246.3750 - val_mae: 1265247.6250 - learning_rate: 3981.0718
# Epoch 118/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 22728152.0000 - mae: 22728154.0000 - val_loss: 15485557.0000 - val_mae: 15485559.0000 - learning_rate: 5011.8726
# Epoch 119/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 76460784.0000 - mae: 76460784.0000 - val_loss: 18110200.0000 - val_mae: 18110200.0000 - learning_rate: 6309.5732
# Epoch 120/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 257693488.0000 - mae: 257693488.0000 - val_loss: 757680192.0000 - val_mae: 757680192.0000 - learning_rate: 7943.2822
# Epoch 121/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2858080000.0000 - mae: 2858080000.0000 - val_loss: 85992456.0000 - val_mae: 85992456.0000 - learning_rate: 10000.0000
# Epoch 122/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 697633344.0000 - mae: 697633344.0000 - val_loss: 6005626880.0000 - val_mae: 6005626880.0000 - learning_rate: 12589.2539
# Epoch 123/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9713075200.0000 - mae: 9713075200.0000 - val_loss: 1450278528.0000 - val_mae: 1450278528.0000 - learning_rate: 15848.9316
# Epoch 124/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2440453376.0000 - mae: 2440453376.0000 - val_loss: 528976960.0000 - val_mae: 528976960.0000 - learning_rate: 19952.6230
# Epoch 125/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 686745024.0000 - mae: 686745024.0000 - val_loss: 1069424704.0000 - val_mae: 1069424704.0000 - learning_rate: 25118.8652
# Epoch 126/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 11205157888.0000 - mae: 11205157888.0000 - val_loss: 4627331584.0000 - val_mae: 4627331584.0000 - learning_rate: 31622.7773
# Epoch 127/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 30906386432.0000 - mae: 30906386432.0000 - val_loss: 2330262784.0000 - val_mae: 2330262784.0000 - learning_rate: 39810.7188
# Epoch 128/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 39289942016.0000 - mae: 39289942016.0000 - val_loss: 7815982592.0000 - val_mae: 7815982592.0000 - learning_rate: 50118.7227
# Epoch 129/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 9031746560.0000 - mae: 9031746560.0000 - val_loss: 1041856000.0000 - val_mae: 1041856000.0000 - learning_rate: 63095.7344
# Epoch 130/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1309021056.0000 - mae: 1309021056.0000 - val_loss: 34348416.0000 - val_mae: 34348416.0000 - learning_rate: 79432.8203
# Epoch 131/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 258667331584.0000 - mae: 258667331584.0000 - val_loss: 96061718528.0000 - val_mae: 96061718528.0000 - learning_rate: 100000.0000
# Epoch 132/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 225412743168.0000 - mae: 225412743168.0000 - val_loss: 82398175232.0000 - val_mae: 82398175232.0000 - learning_rate: 125892.5391
# Epoch 133/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 381214851072.0000 - mae: 381214851072.0000 - val_loss: 16414833664.0000 - val_mae: 16414833664.0000 - learning_rate: 158489.3125
# Epoch 134/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 292725522432.0000 - mae: 292725522432.0000 - val_loss: 210144100352.0000 - val_mae: 210144100352.0000 - learning_rate: 199526.2344
# Epoch 135/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1333365178368.0000 - mae: 1333365178368.0000 - val_loss: 7713047552.0000 - val_mae: 7713047552.0000 - learning_rate: 251188.6406
# Epoch 136/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 94923243520.0000 - mae: 94923243520.0000 - val_loss: 23470237696.0000 - val_mae: 23470237696.0000 - learning_rate: 316227.7812
# Epoch 137/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 90138460160.0000 - mae: 90138460160.0000 - val_loss: 2032204513280.0000 - val_mae: 2032204513280.0000 - learning_rate: 398107.1562
# Epoch 138/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 37789601103872.0000 - mae: 37789601103872.0000 - val_loss: 12594567970816.0000 - val_mae: 12594567970816.0000 - learning_rate: 501187.2188
# Epoch 139/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 7653041373184.0000 - mae: 7653041373184.0000 - val_loss: 78518648832.0000 - val_mae: 78518648832.0000 - learning_rate: 630957.3750
# Epoch 140/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 285301473280.0000 - mae: 285301473280.0000 - val_loss: 23121033216.0000 - val_mae: 23121033216.0000 - learning_rate: 794328.2500
# Epoch 141/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 80919904256.0000 - mae: 80919904256.0000 - val_loss: 3751135232.0000 - val_mae: 3751135232.0000 - learning_rate: 1000000.0000
# Epoch 142/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 149114929152.0000 - mae: 149114929152.0000 - val_loss: 1799477919744.0000 - val_mae: 1799477919744.0000 - learning_rate: 1258925.3750
# Epoch 143/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 56417805402112.0000 - mae: 56417805402112.0000 - val_loss: 5990336954368.0000 - val_mae: 5990336954368.0000 - learning_rate: 1584893.2500
# Epoch 144/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 48261524094976.0000 - mae: 48261524094976.0000 - val_loss: 11329790279680.0000 - val_mae: 11329790279680.0000 - learning_rate: 1995262.3750
# Epoch 145/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5634167144448.0000 - mae: 5634167144448.0000 - val_loss: 51566849556480.0000 - val_mae: 51566849556480.0000 - learning_rate: 2511886.5000
# Epoch 146/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 56089248792576.0000 - mae: 56089248792576.0000 - val_loss: 11880771878912.0000 - val_mae: 11880771878912.0000 - learning_rate: 3162277.7500
# Epoch 147/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 60490516529152.0000 - mae: 60490516529152.0000 - val_loss: 13396314423296.0000 - val_mae: 13396314423296.0000 - learning_rate: 3981071.7500
# Epoch 148/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2887523424534528.0000 - mae: 2887523424534528.0000 - val_loss: 459071169757184.0000 - val_mae: 459071169757184.0000 - learning_rate: 5011872.5000
# Epoch 149/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1177286371966976.0000 - mae: 1177286371966976.0000 - val_loss: 7927703797760.0000 - val_mae: 7927703797760.0000 - learning_rate: 6309573.5000
# Epoch 150/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 37051898527744.0000 - mae: 37051898527744.0000 - val_loss: 1172084097024.0000 - val_mae: 1172084097024.0000 - learning_rate: 7943282.5000
# Epoch 151/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 16934728892416.0000 - mae: 16934728892416.0000 - val_loss: 6858637574144.0000 - val_mae: 6858637574144.0000 - learning_rate: 10000000.0000
# Epoch 152/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6745061064704.0000 - mae: 6745061064704.0000 - val_loss: 40060640559104.0000 - val_mae: 40060640559104.0000 - learning_rate: 12589254.0000
# Epoch 153/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1125065408118784.0000 - mae: 1125065408118784.0000 - val_loss: 27174498599960576.0000 - val_mae: 27174498599960576.0000 - learning_rate: 15848932.0000
# Epoch 154/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 68269995523571712.0000 - mae: 68269995523571712.0000 - val_loss: 7628398788608000.0000 - val_mae: 7628398788608000.0000 - learning_rate: 19952624.0000
# Epoch 155/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5848457503834112.0000 - mae: 5848457503834112.0000 - val_loss: 1028425087188992.0000 - val_mae: 1028425087188992.0000 - learning_rate: 25118864.0000
# Epoch 156/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 772801384415232.0000 - mae: 772801384415232.0000 - val_loss: 151908413079552.0000 - val_mae: 151908413079552.0000 - learning_rate: 31622776.0000
# Epoch 157/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 147600795762688.0000 - mae: 147600795762688.0000 - val_loss: 93246164303872.0000 - val_mae: 93246164303872.0000 - learning_rate: 39810716.0000
# Epoch 158/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 84655457959936.0000 - mae: 84655457959936.0000 - val_loss: 4170312843264.0000 - val_mae: 4170312843264.0000 - learning_rate: 50118724.0000
# Epoch 159/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 126452410351616.0000 - mae: 126452410351616.0000 - val_loss: 4787410529419264.0000 - val_mae: 4787410529419264.0000 - learning_rate: 63095736.0000
# Epoch 160/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 208775422500929536.0000 - mae: 208775422500929536.0000 - val_loss: 746746516143603712.0000 - val_mae: 746746516143603712.0000 - learning_rate: 79432824.0000
# Epoch 161/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1146353640617803776.0000 - mae: 1146353640617803776.0000 - val_loss: 85698161061920768.0000 - val_mae: 85698161061920768.0000 - learning_rate: 100000000.0000
# Epoch 162/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 369080970835394560.0000 - mae: 369080970835394560.0000 - val_loss: 34379119407923200.0000 - val_mae: 34379119407923200.0000 - learning_rate: 125892544.0000
# Epoch 163/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 24934662417678336.0000 - mae: 24934662417678336.0000 - val_loss: 6319375971778560.0000 - val_mae: 6319375971778560.0000 - learning_rate: 158489312.0000
# Epoch 164/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 10451291813707776.0000 - mae: 10451291813707776.0000 - val_loss: 1785920416120832.0000 - val_mae: 1785920416120832.0000 - learning_rate: 199526224.0000
# Epoch 165/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3695889419862016.0000 - mae: 3695889419862016.0000 - val_loss: 12895621052628992.0000 - val_mae: 12895621052628992.0000 - learning_rate: 251188640.0000
# Epoch 166/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5060306004013481984.0000 - mae: 5060306004013481984.0000 - val_loss: 9218181792215859200.0000 - val_mae: 9218181792215859200.0000 - learning_rate: 316227776.0000
# Epoch 167/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2519921771432378368.0000 - mae: 2519921771432378368.0000 - val_loss: 34910956618252288.0000 - val_mae: 34910956618252288.0000 - learning_rate: 398107168.0000
# Epoch 168/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 138125564123807744.0000 - mae: 138125564123807744.0000 - val_loss: 39719513956024320.0000 - val_mae: 39719513956024320.0000 - learning_rate: 501187232.0000
# Epoch 169/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2035655756312739840.0000 - mae: 2035655756312739840.0000 - val_loss: 205083846570409984.0000 - val_mae: 205083846570409984.0000 - learning_rate: 630957376.0000
# Epoch 170/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1268541886776213504.0000 - mae: 1268541886776213504.0000 - val_loss: 2473620787030917120.0000 - val_mae: 2473620787030917120.0000 - learning_rate: 794328256.0000
# Epoch 171/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 60513201333349646336.0000 - mae: 60513201333349646336.0000 - val_loss: 9454534460990029824.0000 - val_mae: 9454534460990029824.0000 - learning_rate: 1000000000.0000
# Epoch 172/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11153693342275993600.0000 - mae: 11153693342275993600.0000 - val_loss: 767814395882373120.0000 - val_mae: 767814395882373120.0000 - learning_rate: 1258925440.0000
# Epoch 173/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1245008352212156416.0000 - mae: 1245008352212156416.0000 - val_loss: 854120354946220032.0000 - val_mae: 854120354946220032.0000 - learning_rate: 1584893184.0000
# Epoch 174/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 41079649971757645824.0000 - mae: 41079649971757645824.0000 - val_loss: 155424870232276074496.0000 - val_mae: 155424870232276074496.0000 - learning_rate: 1995262336.0000
# Epoch 175/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 90390745366348693504.0000 - mae: 90390745366348693504.0000 - val_loss: 134969995713782480896.0000 - val_mae: 134969995713782480896.0000 - learning_rate: 2511886336.0000
# Epoch 176/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 289248594287776497664.0000 - mae: 289248594287776497664.0000 - val_loss: 7677393817015681024.0000 - val_mae: 7677393817015681024.0000 - learning_rate: 3162277632.0000
# Epoch 177/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 65905707733265416192.0000 - mae: 65905707733265416192.0000 - val_loss: 81790444578722021376.0000 - val_mae: 81790444578722021376.0000 - learning_rate: 3981071616.0000
# Epoch 178/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 451887386698169974784.0000 - mae: 451887386698169974784.0000 - val_loss: 52448965240821907456.0000 - val_mae: 52448965240821907456.0000 - learning_rate: 5011872256.0000
# Epoch 179/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 47851634446206763008.0000 - mae: 47851634446206763008.0000 - val_loss: 13487015346091065344.0000 - val_mae: 13487015346091065344.0000 - learning_rate: 6309573632.0000
# Epoch 180/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1302086494502380371968.0000 - mae: 1302086494502380371968.0000 - val_loss: 4403324729867278221312.0000 - val_mae: 4403324729867278221312.0000 - learning_rate: 7943282176.0000
# Epoch 181/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1870150848250524991488.0000 - mae: 1870150848250524991488.0000 - val_loss: 170656308054833758208.0000 - val_mae: 170656308054833758208.0000 - learning_rate: 10000000000.0000
# Epoch 182/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 245685855634361155584.0000 - mae: 245685855634361155584.0000 - val_loss: 302696501104779198464.0000 - val_mae: 302696501104779198464.0000 - learning_rate: 12589253632.0000
# Epoch 183/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 700083154699860049920.0000 - mae: 700083154699860049920.0000 - val_loss: 7926048239695828090880.0000 - val_mae: 7926048239695828090880.0000 - learning_rate: 15848932352.0000
# Epoch 184/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 68576334043968679444480.0000 - mae: 68576334043968679444480.0000 - val_loss: 14691494085620328824832.0000 - val_mae: 14691494085620328824832.0000 - learning_rate: 19952623616.0000
# Epoch 185/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 35676897003080305868800.0000 - mae: 35676897003080305868800.0000 - val_loss: 368688942713290096640.0000 - val_mae: 368688942713290096640.0000 - learning_rate: 25118863360.0000
# Epoch 186/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1011026239303563870208.0000 - mae: 1011026239303563870208.0000 - val_loss: 317541104348406218752.0000 - val_mae: 317541104348406218752.0000 - learning_rate: 31622776832.0000
# Epoch 187/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 315053921085446684672.0000 - mae: 315053921085446684672.0000 - val_loss: 99947366183442841600.0000 - val_mae: 99947366183442841600.0000 - learning_rate: 39810715648.0000
# Epoch 188/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 98663945842758516736.0000 - mae: 98663945842758516736.0000 - val_loss: 5283111590021824512.0000 - val_mae: 5283111590021824512.0000 - learning_rate: 50118721536.0000
# Epoch 189/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 10442880387852202409984.0000 - mae: 10442880387852202409984.0000 - val_loss: 512170354413234861113344.0000 - val_mae: 512170354413234861113344.0000 - learning_rate: 63095734272.0000
# Epoch 190/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 309077430740418713092096.0000 - mae: 309077430740418713092096.0000 - val_loss: 6158932010357680504832.0000 - val_mae: 6158932010357680504832.0000 - learning_rate: 79432826880.0000
# Epoch 191/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 26319853625685546369024.0000 - mae: 26319853625685546369024.0000 - val_loss: 9826075264186887176192.0000 - val_mae: 9826075264186887176192.0000 - learning_rate: 99999997952.0000
# Epoch 192/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 395511199336056632639488.0000 - mae: 395511199336056632639488.0000 - val_loss: 101000247259202070773760.0000 - val_mae: 101000247259202070773760.0000 - learning_rate: 125892542464.0000
# Epoch 193/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 485512935729279572901888.0000 - mae: 485512935729279572901888.0000 - val_loss: 162952466294852483547136.0000 - val_mae: 162952466294852483547136.0000 - learning_rate: 158489313280.0000
# Epoch 194/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 174870432060755574521856.0000 - mae: 174870432060755574521856.0000 - val_loss: 105884301975893571534848.0000 - val_mae: 105884301975893571534848.0000 - learning_rate: 199526236160.0000
# Epoch 195/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 982098961934367531728896.0000 - mae: 982098961934367531728896.0000 - val_loss: 202487369666919911129088.0000 - val_mae: 202487369666919911129088.0000 - learning_rate: 251188641792.0000
# Epoch 196/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1436390603174908593700864.0000 - mae: 1436390603174908593700864.0000 - val_loss: 503017274559364084006912.0000 - val_mae: 503017274559364084006912.0000 - learning_rate: 316227780608.0000
# Epoch 197/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 584406975543550029070336.0000 - mae: 584406975543550029070336.0000 - val_loss: 858391637411557458051072.0000 - val_mae: 858391637411557458051072.0000 - learning_rate: 398107181056.0000
# Epoch 198/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 11063272196275154016272384.0000 - mae: 11063272196275154016272384.0000 - val_loss: 1191505103622425678970880.0000 - val_mae: 1191505103622425678970880.0000 - learning_rate: 501187248128.0000
# Epoch 199/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 11127530276334416632479744.0000 - mae: 11127530276334416632479744.0000 - val_loss: 233493085848695451156480.0000 - val_mae: 233493085848695451156480.0000 - learning_rate: 630957342720.0000
# Epoch 200/200
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 732763689777260453167104.0000 - mae: 732763689777260453167104.0000 - val_loss: 6457104060168814481899520.0000 - val_mae: 6457104060168814481899520.0000 - learning_rate: 794328236032.0000

# %%
plt.semilogx(history_simple.history["learning_rate"], history_simple.history["loss"])
plt.axis([1e-8, 100, 0, 60])
plt.ylim(0,0.5)
plt.ylabel("d/loss")
plt.xlabel("learning rate (log scale)")
plt.title('Learning Rate vs Loss')
# Out:
# Text(0.5, 1.0, 'Learning Rate vs Loss')

# %%
sma=20
n_skip=20
y_lim=(-0.01,0.01)
"""
Plots rate of change of the loss function.
    Parameters:
        sched - learning rate scheduler, an instance of LR_Finder class.
        sma - number of batches for simple moving average to smooth out the curve.
        n_skip - number of batches to skip on the left.
        y_lim - limits for the y axis.
    """
derivatives = [0] * (sma + 1)
for i in range(1 + sma,200):
  derivative = (history_simple.history["loss"][i] - history_simple.history["loss"][i - sma]) / sma
  derivatives.append(derivative)

plt.ylabel("d/loss")
plt.xlabel("learning rate (log scale)")
plt.title('Learning Rate vs Loss Zoomed')
plt.plot(history_simple.history["learning_rate"][20:], derivatives[20:])
plt.xscale('log')
plt.ylim(y_lim)
plt.xlim(1e-5,100)
# Out:
# (1e-05, 100)

# %% [markdown]
# Zooming in into learning rate vs Epoch graph and finind optimal learning rate for our model.
#
# **We take the learning rate where the loss is the minimum.
# The optimal learning rate looks to be around 2e-5.**
#
# Tuning learning rate is the most important parameter .

# %%
##8e-4 is the optimal learning rate.
## 4 layers of LSTM Model
model_simple = Sequential()
#layer 1 of LSTM
model_simple.add(LSTM(units=64,return_sequences=True,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

#layer 2 of LSTM
model_simple.add(LSTM(units=32,return_sequences=True,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

#layer 3 of LSTM
model_simple.add(LSTM(units=32,return_sequences=True,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

#layer 4 of LSTM
model_simple.add(LSTM(units=16,input_shape=(X1.shape[1],3)))
model_simple.add(Dropout(0.2))

##Hidden Layer
model_simple.add(Dense(units=16))
#Output layer of model
model_simple.add(Dense(units=1))

#compiling the model

optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
model_simple.compile(loss=tf.keras.losses.MSE,
              optimizer=optimizer)

history_simple = model_simple.fit(X1, y1, epochs=40, batch_size=32,validation_split=0.3,shuffle=False)
# Out:
# Epoch 1/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0377 - val_loss: 0.4928
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0247 - val_loss: 0.4000
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0184 - val_loss: 0.2976
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0157 - val_loss: 0.1962
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0168 - val_loss: 0.1162
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0169 - val_loss: 0.0614
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0131 - val_loss: 0.0287
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0081 - val_loss: 0.0141
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0044 - val_loss: 0.0086
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030 - val_loss: 0.0086
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - val_loss: 0.0085
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - val_loss: 0.0083
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0028 - val_loss: 0.0092
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030 - val_loss: 0.0087
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - val_loss: 0.0092
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028 - val_loss: 0.0090
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029 - val_loss: 0.0099
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028 - val_loss: 0.0099
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - val_loss: 0.0108
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028 - val_loss: 0.0112
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0026 - val_loss: 0.0111
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0025 - val_loss: 0.0116
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0112
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - val_loss: 0.0105
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0106
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0109
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0097
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0112
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026 - val_loss: 0.0123
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - val_loss: 0.0107
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0024 - val_loss: 0.0114
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0024 - val_loss: 0.0107
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - val_loss: 0.0122
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023 - val_loss: 0.0120
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023 - val_loss: 0.0120
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023 - val_loss: 0.0137
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021 - val_loss: 0.0118
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021 - val_loss: 0.0124

# %%
loss=history_simple.history['loss']
val_loss = history_simple.history['val_loss']

epochs=range(len(loss)) # Get number of epochs


#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r',label='loss')
plt.plot(epochs,val_loss,'blue',label='val loss')
plt.title('Training loss & Val Loss by Epochs')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.figure()

# %% [markdown]
# Since both training loss and validation loss are close to each other there seems to be no overfitting .
# We notice smooth loss curves which is a good sign .
# If there was a lot of jagginess or validation loss decreasing with increasing number of epochs we would be looking at overfitting .
# In this case there appears to be no overfitting .

# %% [markdown]
# # Forecasting Using LSTM(Long Term Short Memory)
# LSTM are type of Re-current Neural Network with 3 gates (input,output & forget).

# %%
##Forecasting for Financial Outlier
lstm_model(sc1,fin_train,3)
# Out:
# Shape of Input Data Initially (3125, 3)
# Shape of Train Part after transformation (3064, 60, 1, 3)
# Shape of Test Part after transformation  (3064,)
# Final Shape  (3064, 60, 3)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.3269
# Epoch 2/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.2157
# Epoch 3/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1067
# Epoch 4/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0230
# Epoch 5/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0120
# Epoch 6/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0117
# Epoch 7/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0105
# Epoch 8/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0112
# Epoch 9/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0097
# Epoch 10/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0104
# Epoch 11/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0097
# Epoch 12/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0089
# Epoch 13/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0088
# Epoch 14/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0094
# Epoch 15/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0086
# Epoch 16/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0092
# Epoch 17/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0087
# Epoch 18/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0081
# Epoch 19/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0076
# Epoch 20/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0079
# Epoch 21/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0086
# Epoch 22/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0077
# Epoch 23/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0075
# Epoch 24/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0079
# Epoch 25/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0072
# Epoch 26/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0072
# Epoch 27/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0069
# Epoch 28/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0070
# Epoch 29/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0069
# Epoch 30/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0072
# Epoch 31/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0061
# Epoch 32/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0066
# Epoch 33/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0071
# Epoch 34/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0069
# Epoch 35/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0061
# Epoch 36/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0064
# Epoch 37/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0064
# Epoch 38/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0062
# Epoch 39/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0062
# Epoch 40/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0060
# Epoch 41/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0065
# Epoch 42/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0060
# Epoch 43/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0055
# Epoch 44/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0059
# Epoch 45/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0056
# Epoch 46/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0057
# Epoch 47/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0059
# Epoch 48/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0057
# Epoch 49/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0057
# Epoch 50/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0059

# %% [markdown]
# Shape of Input Data Initially (3125, 3)
# Shape of Train Part after transformation (3064, 60, 1, 3)
# Shape of Test Part after transformation  (3064,)
# Final Shape  (3064, 60, 3)
#
# Epoch 1/50
# 96/96 [==============================] - 1s 15ms/step - loss: 0.0272
#
# Epoch 2/50
# 96/96 [==============================] - 1s 14ms/step - loss: 0.0064
#
# Epoch 3/50
# 96/96 [==============================] - 1s 12ms/step - loss: 0.0058
#
# Epoch 4/50
# 96/96 [==============================] - 1s 13ms/step - loss: 0.0050

# %%
prepare_test_data_lstm(sc1,fin_test,3)
# Out:
# Shape of Test Dataset (1279, 60, 3)

# %%
predict_data(model,sc2,fin_test,X_test,'Financial Outlier',3)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 1279
#       Predicted -Financial Outlier
# 0                        88.656761
# 1                        88.557838
# 2                        88.446198
# 3                        88.321526
# 4                        88.184532
# ...                            ...
# 1274                     59.709145
# 1275                     59.532806
# 1276                     59.331059
# 1277                     59.104187
# 1278                     58.855755
#
# [1279 rows x 1 columns]

# %%
fin_out_pred = pred_df.copy()
fin_out_actual = fin_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(fin_out_actual,fin_out_pred,'LSTM','Financial')
# Out:
# Result Metrics for LSTM -Financial Outlier Removal Technique
# R2 Score :  0.83
# Mean Squared Error :  28.004
# Mean Absolute Error :  4.189

# %%
##Forecasting For Z-Score Outlier Removed Dataset
lstm_model(sc1,z_train,3)
# Out:
# Shape of Input Data Initially (3437, 3)
# Shape of Train Part after transformation (3376, 60, 1, 3)
# Shape of Test Part after transformation  (3376,)
# Final Shape  (3376, 60, 3)
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1681
# Epoch 2/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0864
# Epoch 3/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0213
# Epoch 4/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0122
# Epoch 5/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0111
# Epoch 6/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0106
# Epoch 7/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0099
# Epoch 8/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0093
# Epoch 9/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0096
# Epoch 10/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0090
# Epoch 11/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0087
# Epoch 12/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0078
# Epoch 13/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0085
# Epoch 14/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0076
# Epoch 15/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0075
# Epoch 16/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0081
# Epoch 17/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0071
# Epoch 18/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0068
# Epoch 19/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0071
# Epoch 20/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0073
# Epoch 21/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0070
# Epoch 22/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0066
# Epoch 23/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0072
# Epoch 24/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0072
# Epoch 25/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0069
# Epoch 26/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0066
# Epoch 27/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0070
# Epoch 28/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0064
# Epoch 29/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0061
# Epoch 30/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0065
# Epoch 31/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0068
# Epoch 32/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0065
# Epoch 33/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0060
# Epoch 34/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0057
# Epoch 35/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0058
# Epoch 36/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0062
# Epoch 37/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0058
# Epoch 38/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0061
# Epoch 39/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0053
# Epoch 40/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0052
# Epoch 41/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0058
# Epoch 42/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0052
# Epoch 43/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0058
# Epoch 44/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0054
# Epoch 45/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0058
# Epoch 46/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0054
# Epoch 47/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0049
# Epoch 48/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0053
# Epoch 49/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0050
# Epoch 50/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0055

# %%
prepare_test_data_lstm(sc1,z_test,3)
# Out:
# Shape of Test Dataset (1412, 60, 3)

# %%
predict_data(model,sc2,z_test,X_test,'Z-Score Outlier',3)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 1412
#       Predicted -Z-Score Outlier
# 0                      82.003624
# 1                      81.936440
# 2                      81.896873
# 3                      81.883766
# 4                      81.893791
# ...                          ...
# 1407                   55.087837
# 1408                   54.926235
# 1409                   54.740784
# 1410                   54.531403
# 1411                   54.301270
#
# [1412 rows x 1 columns]

# %%
z_out_pred = pred_df.copy()
z_out_actual = z_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(z_out_actual,z_out_pred,'LSTM','ZScore')
# Out:
# Result Metrics for LSTM -ZScore Outlier Removal Technique
# R2 Score :  0.837
# Mean Squared Error :  55.071
# Mean Absolute Error :  5.831

# %%
##Forecasting For Mahalanobis Outlier Removed Dataset
lstm_model(sc1,mah_train,3)

# %%
prepare_test_data_lstm(sc1,mah_test,3)

# %%
predict_data(model,sc2,mah_test,X_test,'Mahalanobis Distance Outlier',3)

# %%
mah_out_pred = pred_df.copy()
mah_out_actual = mah_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(mah_out_actual,mah_out_pred,'LSTM','Mahalanobis')

# %%
##Forecasting Vanilla Model-Without Outlier Removal
lstm_model(sc1,van_train,3)
# Out:
# Shape of Input Data Initially (3462, 3)
# Shape of Train Part after transformation (3401, 60, 1, 3)
# Shape of Test Part after transformation  (3401,)
# Final Shape  (3401, 60, 3)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Epoch 1/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1519
# Epoch 2/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0843
# Epoch 3/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0208
# Epoch 4/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0097
# Epoch 5/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0084
# Epoch 6/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0076
# Epoch 7/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0072
# Epoch 8/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0073
# Epoch 9/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0066
# Epoch 10/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0063
# Epoch 11/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0064
# Epoch 12/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0058
# Epoch 13/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0057
# Epoch 14/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0057
# Epoch 15/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0058
# Epoch 16/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0059
# Epoch 17/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0051
# Epoch 18/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0055
# Epoch 19/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0056
# Epoch 20/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0054
# Epoch 21/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0053
# Epoch 22/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0048
# Epoch 23/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0052
# Epoch 24/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0054
# Epoch 25/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0047
# Epoch 26/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0048
# Epoch 27/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0048
# Epoch 28/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0051
# Epoch 29/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0049
# Epoch 30/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0049
# Epoch 31/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048
# Epoch 32/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0047
# Epoch 33/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043
# Epoch 34/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0044
# Epoch 35/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0043
# Epoch 36/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0044
# Epoch 37/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0046
# Epoch 38/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0044
# Epoch 39/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0043
# Epoch 40/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041
# Epoch 41/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0044
# Epoch 42/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0045
# Epoch 43/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0039
# Epoch 44/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0043
# Epoch 45/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0038
# Epoch 46/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0040
# Epoch 47/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0038
# Epoch 48/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0038
# Epoch 49/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0040
# Epoch 50/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0036

# %%
prepare_test_data_lstm(sc1,van_test,3)
# Out:
# Shape of Test Dataset (1424, 60, 3)

# %%
predict_data(model,sc2,van_test,X_test,'Vanilla Model',3)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# 1424
#       Predicted -Vanilla Model
# 0                    76.985916
# 1                    76.943153
# 2                    76.869728
# 3                    76.769157
# 4                    76.646194
# ...                        ...
# 1419                 52.727962
# 1420                 52.588570
# 1421                 52.432598
# 1422                 52.259010
# 1423                 52.069237
#
# [1424 rows x 1 columns]

# %%
van_pred = pred_df.copy()
van_actual = van_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(van_actual,van_pred,'LSTM','Vanilla Model-No')
# Out:
# Result Metrics for LSTM -Vanilla Model-No Outlier Removal Technique
# R2 Score :  0.698
# Mean Squared Error :  104.786
# Mean Absolute Error :  7.786

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,figsize=(24,16))

ax1.plot(van_actual.index,van_actual,label='Actual')
ax1.plot(van_actual.index,van_pred,label='Predicted')
plt.title('Forecasting-No Outlier Removal Technique')
ax1.set_title('LSTM-Vanilla Model')

ax2.plot(z_out_actual.index,z_out_actual,label='Actual')
ax2.plot(z_out_actual.index,z_out_pred,label='Predicted')
ax2.set_title('LSTM-ZScore Outlier Removal Technique')

ax3.plot(fin_out_actual.index,fin_out_actual,label='Actual')
ax3.plot(fin_out_actual.index,fin_out_pred,label='Predicted')
ax3.set_title('LSTM-Financial Outlier Removal Technique')

ax4.plot(mah_out_actual.index,mah_out_actual,label='Actual')
ax4.plot(mah_out_actual.index,mah_out_pred,label='Predicted')
ax4.set_title('LSTM-Forecasting-Mahalanobis Outlier Removal Technique')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.tight_layout(pad=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-2990a303f0ce> in <cell line: 16>()
#      14 ax3.set_title('LSTM-Financial Outlier Removal Technique')
#      15
# ---> 16 ax4.plot(mah_out_actual.index,mah_out_actual,label='Actual')
#      17 ax4.plot(mah_out_actual.index,mah_out_pred,label='Predicted')
#      18 ax4.set_title('LSTM-Forecasting-Mahalanobis Outlier Removal Technique')
#
# NameError: name 'mah_out_actual' is not defined

# %% [markdown]
# # Forecasting Using GRU(Gated Re-current Unit)
# GRU is simply a improved version of standard Re-current Neural Network(RNN) with two gates(update & reset).

# %%
#GRU Model Function
def gru_model(scaler,train_data,n_dim):
##initialize model
##GRU & LSTM use same kind of input shaped data
  prepare_train_data_lstm(scaler,train_data,n_dim)

  global gru_model
  gru_model = Sequential()

# Layer 1 of GRU with Dropout
  gru_model.add(GRU(units=30, return_sequences=True, input_shape=(X1.shape[1],n_dim), activation='tanh'))
  gru_model.add(Dropout(0.2))

# Layer 2 of GRU with Dropout
  gru_model.add(GRU(units=30, return_sequences=True, input_shape=(X1.shape[1],n_dim), activation='tanh'))
  gru_model.add(Dropout(0.2))

# Layer 3 of GRU with Dropout
  gru_model.add(GRU(units=30, return_sequences=True, input_shape=(X1.shape[1],n_dim), activation='tanh'))
  gru_model.add(Dropout(0.2))

# Layer 4 of GRU with Dropout
  gru_model.add(GRU(units=30, activation='tanh'))
  gru_model.add(Dropout(0.2))

# Output layer of GRU model
  gru_model.add(Dense(units=1))

#compiling the model
  gru_model.compile(optimizer='adam',loss='mean_squared_error')
  gru_model.fit(X1, y1, epochs=50, batch_size=32)

# %%
gru_model(sc1,fin_train,3)

# %%
prepare_test_data_lstm(sc1,fin_test,3)

# %%
predict_data(gru_model,sc2,fin_test,X_test,'Financial Outlier',3)

# %%
gru_fin_out_pred = pred_df.copy()
gru_fin_out_actual = fin_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(gru_fin_out_actual,gru_fin_out_pred,'GRU','Financial')

# %%
##Forecasting Using Z-Score Outlier Removal
sc3 = MinMaxScaler(feature_range=(0,1))
sc4 = MinMaxScaler(feature_range=(0,1))
gru_model(sc3,z_train,3)

# %%
prepare_test_data_lstm(sc3,z_test,3)

# %%
predict_data(gru_model,sc4,z_test,X_test,'Z-Score Outlier',3)

# %%
gru_z_out_pred = pred_df.copy()
gru_z_out_actual = z_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(gru_z_out_actual,gru_z_out_pred,'GRU','ZScore')

# %%
sc5 = MinMaxScaler(feature_range=(0,1))
sc6 = MinMaxScaler(feature_range=(0,1))
gru_model(sc5,mah_train,3)

# %%
prepare_test_data_lstm(sc5,mah_test,3)

# %%
predict_data(gru_model,sc6,mah_test,X_test,'Mahalanobis Distance Outlier',3)

# %%
gru_mah_out_pred = pred_df.copy()
gru_mah_out_actual = mah_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(gru_mah_out_actual,gru_mah_out_pred,'GRU','Mahalanobis')

# %%
sc7 = MinMaxScaler(feature_range=(0,1))
sc8 = MinMaxScaler(feature_range=(0,1))
gru_model(sc7,van_train,3)

# %%
prepare_test_data_lstm(sc7,van_test,3)

# %%
predict_data(gru_model,sc8,van_test,X_test,'Vanilla Model',3)

# %%
gru_van_pred = pred_df.copy()
gru_van_actual = van_test.iloc[61:,0].copy()

# %%
result_metrics_forecast(gru_van_actual,gru_van_pred,'GRU','Vanilla Model-No')

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,figsize=(24,16))

ax1.plot(van_actual.index,van_actual,label='Actual')
ax1.plot(van_actual.index,gru_van_pred,label='GRU Predicted',c='yellow')
ax1.plot(van_actual.index,van_pred,label='LSTM Predicted')
plt.title('Forecasting-No Outlier Removal Technique')
ax1.set_title('Vanilla Model')

ax2.plot(z_out_actual.index,z_out_actual,label='Actual')
ax2.plot(z_out_actual.index,gru_z_out_pred,label='GRU Predicted',c='yellow')
ax2.plot(z_out_actual.index,z_out_pred,label='LSTM Predicted')
ax2.set_title('ZScore Outlier Removal Technique')

ax3.plot(fin_out_actual.index,fin_out_actual,label='Actual')
ax3.plot(fin_out_actual.index,gru_fin_out_pred,label='GRU Predicted',c='yellow')
ax3.plot(fin_out_actual.index,fin_out_pred,label='LSTM Predicted')
ax3.set_title('Financial Outlier Removal Technique')

ax4.plot(mah_out_actual.index,mah_out_actual,label='Actual')
ax4.plot(mah_out_actual.index,gru_mah_out_pred,label='GRU Predicted',c='yellow')
ax4.plot(mah_out_actual.index,mah_out_pred,label='LSTM Predicted')
ax4.set_title('Mahalanobis Outlier Removal Technique')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()

plt.tight_layout(pad=3)

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# **General Issues with Traditional RNN's**
#
# Suffer from short memory due to vanishing gradients they forget initial information.
#
# LSTM & GRU tackle short term memory problem.
# They are able to regulate flow of information.
#
# # **LSTM VS GRU**
#
# **Long Term Short Memory(LSTM) :-**
#
# -> Have three gates (input,output & forget gate)
#
# -> More memory consumption and more training time in comparision to GRU.
#
# -> With Bigger datasets LSTM is better suited.
#
# **Modelling Results LSTM :-**
#
# Mahalanobis Distance Outlier Removal (R2 Score): 0.934
#
# Financial Outlier Removal (R2 Score): 0.918
#
# Z-Score Outlier Removal (R2 Score): 0.898
#
# Vanilla Model-No Outlier Removal(R2 Score): 0.728
#
# **Gated Re-current Unit(GRU) :-**
#
# -> Have two gates (reset & update gate)
#
# -> Less memory consumption, faster execution, less training time.
#
# -> More suited for smaller datasets.
#
# **Modelling Results GRU :-**
#
# Mahalanobis Distance Outlier Removal (R2 Score): 0.946
#
# Financial Outlier Removal (R2 Score): 0.915
#
# Z-Score Outlier Removal (R2 Score): 0.901
#
# Vanilla Model-No Outlier Removal(R2 Score): 0.706
#
#
# **Best Outlier Elimination Method :-**
#
# -> In both LSTM & GRU , the order of performance remains same .
#
# ->Mahalanobis Distance as outlier removal is the best techique among all we tested.
#
#
# **Best to worst performing model**
#
# **Mahalanobis Outlier Removal > Financial Outlier Removal > Z-Score Outlier Removal > No Outlier Removal**
#
# # **Overall Verdict :-**
#
# -> Both LSTM & GRU are very capable for long sequential prediction problems.
# Both can be handy according to the type of problem .
#
# -> In our forecasting we observed both being very close at predicting and there is no clear winner.
